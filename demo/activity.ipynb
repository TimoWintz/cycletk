# %%
from cycletk import activities
from cycletk.riders import Rider
import activityio

# %%
rider = Rider(cp=295, wp=20000, weight=65)

# %%
activity = activities.read("test.fit")

# %%
pd.Date str(activity.start)
# Out:
# '2020-11-19 10:17:34'

# %%
activity.set_wp_bal(rider)
activity["wp_bal"].plot(ylim=[0,rider.wp])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
activity.average_power()
# Out:
# 214.43430656934308

# %%
activity.normalized_power()
# Out:
# 260.7771313738503

# %%
activity.maximum_power()
# Out:
# 682.0

# %%
activity.intensity(rider)
# Out:
# 0.8839902758435603

# %%
activity.stress(rider)
# Out:
# 47.072482188669575

# %%
activity.power_curve().plot()
# Out:
# <AxesSubplot:>

# %%
pz = activity.power_zones(rider)
pz["percent"].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
import activityio
activity = activityio.read("test.fit")

# %%
activity.start
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e325084f56b5> in <module>
# ----> 1 activity.start
#
# ~/anaconda3/envs/cycling/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Activity' object has no attribute 'start'
