# %%
from cycletk.activity import *
from cycletk.rider import Rider
from matplotlib import pyplot as plt
import activityio

# %%
rider = Rider(cp=295, wp=20000, weight=65)
x = activityio.read("test.fit")
y = activityio.read("test2.fit")

# %%
rider.update_power_curve(y)
fig, ax = plt.subplots(figsize=(6,4), dpi=200)
rider.update_power_curve(x)

# %%
rider.estimate_model()
print("cp = {0}, wp = {1}".format(rider.cp, rider.wp))
rider.power_curve.plot()
# Out:
# cp = 264.5455233515464, wp = 3311.1310189027345
# <AxesSubplot:>
